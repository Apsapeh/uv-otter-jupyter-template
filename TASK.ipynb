# %% [markdown]
# # ASSIGNMENT CONFIG
# requirements: requirements.txt
# generate:
#     pdf: false
#     zips: true

# %%
import otter
grader = otter.Notebook()

# %% [markdown]
# ### Вопрос 1
# Напишите функцию `square`, которая принимает число и возвращает его квадрат.

# %%
def square(n):
    # BEGIN SOLUTION
    return n ** 2
    # END SOLUTION

# %%
""" # BEGIN TEST CONFIG
name: q1
points: 1
""" # END TEST CONFIG

# Открытый тест
assert square(2) == 4, "2 в квадрате должно быть 4"
assert square(0) == 0, "0 в квадрате должно быть 0"

# Скрытый тест
# BEGIN HIDDEN TESTS
assert square(-3) == 9, "Функция должна работать с отрицательными числами"
# END HIDDEN TESTS

# %%
grader.check("q1")
